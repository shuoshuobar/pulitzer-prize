# %% [markdown]
# # Installation:

# %%
# !pip install playwright
# Out:
# Requirement already satisfied: playwright in /Users/yushuowang/.pyenv/versions/3.11.8/lib/python3.11/site-packages (1.50.0)
# Requirement already satisfied: pyee<13,>=12 in /Users/yushuowang/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from playwright) (12.1.1)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in /Users/yushuowang/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from playwright) (3.1.1)
# Requirement already satisfied: typing-extensions in /Users/yushuowang/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from pyee<13,>=12->playwright) (4.12.2)
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !playwright install

# %%
from playwright.async_api import async_playwright

# %%
playwright = await async_playwright().start()
browser = await playwright.chromium.launch(headless=False)
page = await browser.new_page()

# %% [markdown]
# # Go to the page:

# %%
await page.goto("https://www.pulitzer.org/prize-winners-by-category/210")
# Out:
# <Response url='https://www.pulitzer.org/prize-winners-by-category/210' request=<Request url='https://www.pulitzer.org/prize-winners-by-category/210' method='GET'>>

# %%
html = await page.content()
html
# Out:
# '<!DOCTYPE html><html lang="en" ng-app="app" ng-controller="global" class="js ng-scope wf-adobegaramondpro-n7-active wf-adobegaramondpro-n6-active wf-adobegaramondpro-n4-active wf-adobegaramondpro-i4-active wf-acuminpro-n4-active wf-adobegaramondpro-i7-active wf-active"><head><meta http-equiv="origin-trial" content=""><style type="text/css">@charset "UTF-8";[ng\\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide:not(.ng-hide-animate){display:none !important;}ng\\:form{display:block;}.ng-animate-shim{visibility:hidden;}.ng-anchor{position:absolute;}</style>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no">\n    <!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags -->\n    <title ng-bind="global.pageTitle" class="ng-binding">International Reporting - The Pulitzer Prizes</title>\n    <!-- meta tags for search engines and etc -->\n    <!-- ngIf: global.pageCanocialUrl --><link ng-if="global.pageCanocialUrl" rel="canonical" ng-href="https://www.pulitzer.org/prize-winners-by-category/210" class="ng-scope" href="https://www.pulitzer.org/prize-winners-by-category/210"><!-- end ngIf: global.pageCanocialUrl -->\n    <!-- ngIf: global.doNotFollow -->\n    <!-- ngIf: global.pageDescription --><meta ng-if="global.pageDescription" name="description" content="For a distinguished example of reporting on international affairs, using any available journalistic tool, Fifteen thousand dollars ($15,000).\n" class="ng-scope"><!-- end ngIf: global.pageDescription -->\n    <!-- ngIf: global.controller --><meta ng-if="global.controller" name="ngController" content="winnersByCategoryCtrl" class="ng-scope"><!-- end ngIf: global.controller -->\n    <!-- ngIf: global.pageTitle --><meta ng-if="global.pageTitle" name="pageTitle" content="International Reporting" class="ng-scope"><!-- end ngIf: global.pageTitle -->\n    <!-- ngIf: global.winnersHtmlTitle -->\n    <!-- ngIf: global.pageNid -->\n    <!-- ngIf: global.authorName -->\n    <!-- ngIf: global.pageContentType --><meta ng-if="global.pageContentType" name="pageContentType" content="lander" class="ng-scope"><!-- end ngIf: global.pageContentType -->\n    <!-- ngIf: global.pageYear.yearTid -->\n    <!-- ngIf: global.awardCategory.awardTid -->\n    <!-- ngIf: global.eventType -->\n    <!-- ngIf: global.topics -->\n    <!-- ngIf: global.date -->\n    <!-- ngIf: global.defaultImage.fullPath --><meta ng-if="global.defaultImage.fullPath" name="pageImage" content="https://www.pulitzer.org/img/two_medals.png" class="ng-scope"><!-- end ngIf: global.defaultImage.fullPath -->\n    <!-- ngIf: global.defaultImage.fullPath --><meta ng-if="global.defaultImage.fullPath" name="pageImageUrl" content="https://www.pulitzer.org/img/two_medals.png" class="ng-scope"><!-- end ngIf: global.defaultImage.fullPath -->\n    <!-- ngIf: global.defaultImage.filemime --><meta ng-if="global.defaultImage.filemime" name="pageImageType" content="image/png" class="ng-scope"><!-- end ngIf: global.defaultImage.filemime -->\n    <!-- ngIf: global.defaultImage.width --><meta ng-if="global.defaultImage.width" name="pageImageWidth" content="566" class="ng-scope"><!-- end ngIf: global.defaultImage.width -->\n    <!-- ngIf: global.defaultImage.height --><meta ng-if="global.defaultImage.height" name="pageImageHeight" content="326" class="ng-scope"><!-- end ngIf: global.defaultImage.height -->\n    <!-- ngIf: global.pageTeaserImage.fullPath -->\n    <!-- ngIf: global.pageTeaserImage.fullPath -->\n    <!-- ngIf: global.pageTeaserImage.filemime -- ...

# %% [markdown]
# # Scraping:

# %%
from bs4 import BeautifulSoup

# Take the HTML from currently fully loaded page
# notice: THERE'S NO REQUESTS ANYWHERE!!!!
soup_doc = BeautifulSoup(html)

# %%
# Access the winners' table
rows = soup_doc.find_all('div', class_='row table-row ng-scope')
    
for row in rows:
    # Extract Year: 
    year = row.find('div', class_='col-sm-4 body table-category ng-scope')
    if year:
        year = year.text.strip()
    else:
        year = "N/A"
        
    # Extract the Winners list: 
    winners = row.find_all('div', class_='col-sm-8 table-winners angular-animate ng-trans ng-trans-fade-down')
    for winner in winners:
        winner_name = winner.text.strip()
        print(f"Year: {year}, Winner: {winner_name}")
# Out:
# Year: 2024, Winner: Staff of The New York Times
# For its wide-ranging and revelatory coverage of Hamas’ lethal attack in southern Israel on October 7, Israel’s intelligence failures and the Israeli military’s sweeping, deadly response in Gaza.
# Year: 2023, Winner: Staff of The New York Times
# For their unflinching coverage of Russia’s invasion of Ukraine, including an eight-month investigation into Ukrainian deaths in the town of Bucha and the Russian unit responsible for the killings.
# Year: 2022, Winner: Staff of The New York Times, notably Azmat Khan, contributing writer
# For courageous and relentless reporting that exposed the vast civilian toll of U.S.-led airstrikes, challenging official accounts of American military engagements in Iraq, Syria and Afghanistan. (Moved by the Board from the Public Service category, where it was also nominated.)
# Year: 2021, Winner: Megha Rajagopalan, Alison Killing and Christo Buschek of BuzzFeed News
# For a series of clear and compelling stories that used satellite imagery and architectural expertise, as well as interviews with two dozen former prisoners, to identify a vast new infrastructure built by the Chinese government for the mass detention of Muslims. (Moved by the Board from the Explanatory Reporting category, where it was also entered and nominated.)
# Year: 2020, Winner: Staff of The New York Times
# For a set of enthralling stories, reported at great risk, exposing the predations of Vladimir Putin’s regime.
# Year: 2019, Winner: Maggie Michael, Maad al-Zikry and Nariman El-Mofty of Associated Press
# For a revelatory yearlong series detailing the atrocities of the war in Yemen, including theft of food aid, deployment of child soldiers and torture of prisoners. The reporting was supported by the independent Pulitzer Center for Crisis Reporting.
# Year: 2019, Winner: Staff of Reuters, with notable contributions from Wa Lone and Kyaw Soe Oo
# Year: 1959, Winner: Joseph Martin and Philip Santora of New York Daily News
# For their exclusive series of articles disclosing the brutality of the Batista government in Cuba long before its downfall and forecasting the triumph of the revolutionary party led by Fidel Castro.
# Year: 1958, Winner: Staff of The New York Times
# For its distinguished coverage of foreign news, which was characterized by admirable initiative, continuity and high quality during the year.
# Year: 1957, Winner: Russell Jones of United Press
# For his excellent and sustained coverage of the Hungarian revolt against Communist domination, during which he worked at great personal risk within Russian-held Budapest and gave front-line eyewitness reports of the ruthless Soviet repression of the Hungarian people.
# Year: 1956, Winner: William Randolph Hearst Jr., J. Kingsbury-Smith and Frank Connif of International News Service
# For a series of exclusive interviews with the leaders of the Soviet Union.
# Year: 1955, Winner: Harrison E. Salisbury of The New York Times
# For his distinguished series of articles, "Russia Re-Viewed," based on his six years as a Times correspondent in Russia. The perceptive and well-written Salisbury articles made a valuable contribution to American understanding of what is going on inside Russia. This was principally due to the writer's wide range of subject matter and depth of background plus a number of illuminating photographs which he took.
# Year: 1954, Winner: Jim G. Lucas of Scripps-Howard Newspapers
# For his notable front-line human interest reporting of the Korean War, the cease-fire and the prisoner-of-war exchanges, climaxing 26 months of distinguished service as a war correspondent.
# Year: 1953, Winner: Austin Wehrwein of The Milwaukee Journal
# For a series of articles on Canada.
# Year: 1952, Winner: John M. Hightower of Associated Press
# For the sustained quality of his coverage of news of international affairs during the year.
# Year: 1951, Winner: Keyes Beech, Homer Bigart, Marguerite Higgins, Relman Morin, Fred Sparks and Don Whitehead
# For their reporting of the Korean War.
# Year: 1950, Winner: Edmund Stevens of The Christian Science Monitor
# For his series of 43 articles written over a three-year residence in Moscow entitled, "This Is Russia Uncensored."
# Year: 1949, Winner: Price Day of The Baltimore Sun
# For his series of 12 articles entitled, "Experiment in Freedom: India and Its First Year of Independence."
# Year: 1948, Winner: Paul W. Ward of The Baltimore Sun
# For his series of articles published in 1947 on "Life in the Soviet Union."

# %%
winners = []
rows = soup_doc.find_all('div', class_='row table-row ng-scope')
    
for row in rows:
    # Extract the Winners list: 
    winner_elements = row.find_all('div', class_='col-sm-8 table-winners angular-animate ng-trans ng-trans-fade-down')
    for winner in winner_elements:
            winner_name = winner.text.strip()  
            # Get rid of the winner info expansion line
            winner_name = winner_name.split('\n')[0].strip()
            winners.append(winner_name)

winners
# Out:
# ['Staff of The New York Times',
#  'Staff of The New York Times',
#  'Staff of The New York Times, notably Azmat Khan, contributing writer',
#  'Megha Rajagopalan, Alison Killing and Christo Buschek of BuzzFeed News',
#  'Staff of The New York Times',
#  'Maggie Michael, Maad al-Zikry and Nariman El-Mofty of Associated Press',
#  'Staff of Reuters, with notable contributions from Wa Lone and Kyaw Soe Oo',
#  'Clare Baldwin, Andrew R.C. Marshall and Manuel Mogato of Reuters',
#  'The New York Times Staff',
#  'Alissa J. Rubin of The New York Times',
#  'The New York Times Staff',
#  'Jason Szep and Andrew R.C. Marshall of Reuters',
#  'David Barboza of The New York Times',
#  'Jeffrey Gettleman of The New York Times',
#  'Clifford J. Levy and Ellen Barry of The New York Times',
#  'Anthony Shadid of The Washington Post',
#  'Staff of The New York Times',
#  'Steve Fainaru of The Washington Post',
#  'Staff of The Wall Street Journal',
#  'Joseph Kahn and Jim Yardley of The New York Times',
#  'Dele Olojede of Newsday, Long Island, NY',
#  'Kim Murphy of Los Angeles Times',
#  'Anthony Shadid of The Washington Post',
#  'Kevin Sullivan and Mary Jordan of The Washington Post',
#  'Barry Bearak of The New York Times',
#  'Ian Johnson of The Wall Street Journal',
#  'Paul Salopek of Chicago Tribune',
#  'Mark Schoofs of The Village Voice',
#  'Staff of The Wall Street Journal',
#  'Staff of The New York Times',
#  'John F. Burns of The New York Times',
#  'David Rohde of The Christian Science Monitor',
#  'Mark Fritz of Associated Press',
#  'Dallas Morning News Team of The Dallas Morning News',
#  'John F. Burns of The New York Times',
#  'Roy Gutman of Newsday, Long Island, NY',
#  'Patrick J. Sloyan of Newsday, Long Island, NY',
#  'Caryle Murphy of The Washington Post',
#  'Serge Schmemann of The New York Times',
#  'Nicholas D. Kristof and Sheryl WuDunn of The New York Times',
#  'Bill Keller of The New York Times',
#  'Glenn Frankel of The Washington Post',
#  'Thomas L. Friedman of The New York Times',
#  'Michael Parks of Los Angeles Times',
#  'Lewis M. Simons, Pete Carey and Katherine Ellison of San Jose (CA) Mercury News',
#  'Josh Friedman, Dennis Bell, and Ozier Muhammad of Newsday, Long Island, NY',
#  'Karen Elliott House of The Wall Street Journal',
#  'Thomas L. Friedman and Loren Jenkins of The New York Times and The Washington Post, (respectively)',
#  'John Darnton of The New York Times',
#  'Shirley Christian of The Miami Herald',
#  'Joel Brinkley and Jay Mather of Louisville Courier-Journal',
#  'Richard Ben Cramer of The Philadelphia Inquirer',
#  'Henry Kamm of The New York Times',
#  'Sydney H. Schanberg of The New York Times',
#  'William Mullen and Ovie Carter of Chicago Tribune',
#  'Hedrick Smith of The New York Times',
#  'Max Frankel of The New York Times',
#  'Peter R. Kann of The Wall Street Journal',
#  'Jimmie Lee Hoagland of The Washington Post',
#  'Seymour M. Hersh of Dispatch News Service, Washington, DC',
#  'William Tuohy of Los Angeles Times',
#  'Alfred Friendly of The Washington Post',
#  'R. John Hughes of The Christian Science Monitor',
#  'Peter Arnett of Associated Press',
#  'J. A. Livingston of Philadelphia Bulletin',
#  'Malcolm W. Browne and David Halberstam of Associated Press and The New York Times, (respectively)',
#  'Hal Hendrix of The Miami (FL) News',
#  'Walter Lippmann of New York Herald Tribune Syndicate',
#  'Lynn Heinzerling of Associated Press',
#  'A. M. Rosenthal of The New York Times',
#  'Joseph Martin and Philip Santora of New York Daily News',
#  'Staff of The New York Times',
#  'Russell Jones of United Press',
#  'William Randolph Hearst Jr., J. Kingsbury-Smith and Frank Connif of International News Service',
#  'Harrison E. Salisbury of The New York Times',
#  'Jim G. Lucas of Scripps-Howard Newspapers',
#  'Austin Wehrwein of The Milwaukee Journal',
#  'John M. Hightower of Associated Press',
#  'Keyes Beech, Homer Bigart, Marguerite Higgins, Relman Morin, Fred Sparks and Don Whitehead',
#  'Edmund Stevens of The Christian Science Monitor',
#  'Price Day of The Baltimore Sun',
#  'Paul W. Ward of The Baltimore Sun']

# %%
len(winners)
# Out:
# 82

# %%
# !pip install pandas
import pandas as pd
# Out:
# Requirement already satisfied: pandas in /Users/yushuowang/.pyenv/versions/3.11.8/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in /Users/yushuowang/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from pandas) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/yushuowang/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/yushuowang/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/yushuowang/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /Users/yushuowang/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /Users/yushuowang/.pyenv/versions/3.11.8/lib/python3.11/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /Users/yushuowang/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from openpyxl) (2.0.0)
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
df_winner_annual = pd.read_excel("pulitzer_winners_annual.xlsx")
df_winner_annual
# Out:
#     Year              News Organization  \
# 0   2024             The New York Times
# 1   2023             The New York Times
# 2   2022             The New York Times
# 3   2021                  BuzzFeed News
# 4   2020             The New York Times
# ..   ...                            ...
# 77  1952               Associated Press
# 78  1951                        Unknown
# 79  1950  The Christian Science Monitor
# 80  1949              The Baltimore Sun
# 81  1948              The Baltimore Sun
#
#                                    Winner Description
# 0   For its wide-ranging and revelatory coverage o...
# 1   For their unflinching coverage of Russia’s inv...
# 2   For courageous and relentless reporting that e...
# 3   For a series of clear and compelling stories t...
# 4   For a set of enthralling stories, reported at ...
# ..                                                ...
# 77  For the sustained quality of his coverage of n...
# 78             For their reporting of the Korean War.
# 79  For his series of 43 articles written over a t...
# 80  For his series of 12 articles entitled, "Exper...
# 81  For his series of articles published in 1947 o...
#
# [82 rows x 3 columns]

# %%
df_winner_annual['News Organization'].value_counts()
# Out:
# News Organization
# The New York Times                            28
# The Washington Post                            8
# The Wall Street Journal                        5
# Associated Press                               4
# Newsday                                        4
# The Christian Science Monitor                  3
# Reuters                                        3
# Los Angeles Times                              3
# The Baltimore Sun                              2
# Chicago Tribune                                2
# The Village Voice                              1
# Associated Press and The New York Times        1
# Unknown                                        1
# The Milwaukee Journal                          1
# Scripps-Howard Newspapers                      1
# International News Service                     1
# United Press                                   1
# New York Daily News                            1
# New York Herald Tribune Syndicate              1
# The Miami News                                 1
# Philadelphia Bulletin                          1
# Dispatch News Service                          1
# The Philadelphia Inquirer                      1
# Louisville Courtier-Journal                    1
# BuzzFeed News                                  1
# The New York Times and The Washington Post     1
# San Jose Mercury News                          1
# The Dallas Morning News                        1
# The Associated Press                           1
# The Miami Herald                               1
# Name: count, dtype: int64

# %%
df_newsorg_counts = pd.read_excel("news_org_counts.xlsx")
df_newsorg_counts
# Out:
#                     News Organization  count
# 0                  The New York Times     30
# 1                 The Washington Post      9
# 2             The Wall Street Journal      5
# 3                The Associated Press      6
# 4                             Newsday      4
# 5       The Christian Science Monitor      3
# 6                             Reuters      3
# 7                   Los Angeles Times      3
# 8                   The Baltimore Sun      2
# 9                     Chicago Tribune      2
# 10                  The Village Voice      1
# 11                            Unknown      1
# 12              The Milwaukee Journal      1
# 13          Scripps-Howard Newspapers      1
# 14         International News Service      1
# 15                       United Press      1
# 16                New York Daily News      1
# 17  New York Herald Tribune Syndicate      1
# 18                     The Miami News      1
# 19              Philadelphia Bulletin      1
# 20              Dispatch News Service      1
# 21          The Philadelphia Inquirer      1
# 22        Louisville Courtier-Journal      1
# 23                      BuzzFeed News      1
# 24              San Jose Mercury News      1
# 25            The Dallas Morning News      1
# 26                   The Miami Herald      1

# %%
df_newsorg_counts = df_newsorg_counts.sort_values(by='count', ascending=False)
df_newsorg_counts
# Out:
#                     News Organization  count
# 0                  The New York Times     30
# 1                 The Washington Post      9
# 3                The Associated Press      6
# 2             The Wall Street Journal      5
# 4                             Newsday      4
# 5       The Christian Science Monitor      3
# 6                             Reuters      3
# 7                   Los Angeles Times      3
# 9                     Chicago Tribune      2
# 8                   The Baltimore Sun      2
# 18                     The Miami News      1
# 25            The Dallas Morning News      1
# 24              San Jose Mercury News      1
# 23                      BuzzFeed News      1
# 22        Louisville Courtier-Journal      1
# 21          The Philadelphia Inquirer      1
# 20              Dispatch News Service      1
# 19              Philadelphia Bulletin      1
# 13          Scripps-Howard Newspapers      1
# 17  New York Herald Tribune Syndicate      1
# 16                New York Daily News      1
# 15                       United Press      1
# 14         International News Service      1
# 12              The Milwaukee Journal      1
# 11                            Unknown      1
# 10                  The Village Voice      1
# 26                   The Miami Herald      1

# %%
df_tenyears_major_events = pd.read_excel("Ten Years Major Events Blotter.xlsx")
df_tenyears_major_events
# Out:
#       Year Pulitzer Prize Winner of International Reporting  \
# 0   2024.0                               The New York Times
# 1   2023.0                               The New York Times
# 2   2022.0                               The New York Times
# 3      NaN                                              NaN
# 4      NaN                                              NaN
# 5   2021.0                                    BuzzFeed News
# 6   2020.0                               The New York Times
# 7   2019.0                                 Associated Press
# 8      NaN                                          Reuters
# 9   2018.0                                          Reuters
# 10  2017.0                               The New York Times
# 11  2016.0                               The New York Times
# 12  2015.0                               The New York Times
# 13  2014.0                                          Reuters
#
#                                    Reporting Overview  \
# 0   For its wide-ranging and revelatory coverage o...
# 1   For their unflinching coverage of Russia’s inv...
# 2   For courageous and relentless reporting that e...
# 3                                                 NaN
# 4                                                 NaN
# 5   For a series of clear and compelling stories t...
# 6   For a set of enthralling stories, reported at ...
# 7   For a revelatory yearlong series detailing the...
# 8   For expertly exposing the military units and B...
# 9   For relentless reporting that exposed the brut...
# 10  For agenda-setting reporting on Vladimir Putin...
# 11  For thoroughly reported and movingly written a...
# 12  For courageous front-line reporting and vivid ...
# 13  For their courageous reports on the violent pe...
#
#                                               January  \
# 0                                                 NaN
# 1                                                 NaN
# 2   " … a hidden Pentagon archive of the American ...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   "In 2006, Russian President Vladimir V. Putin ...
# 7   "The war in Yemen began in March 2015 after Ho...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  "Parveena’s story — she was one of six policew...
# 12                                                NaN
# 13                                                NaN
#
#                                February  \
# 0                                   NaN
# 1   Russia’s invasion of Ukraine (2022)
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                                   NaN
# 10                                  NaN
# 11                                  NaN
# 12                                  NaN
# 13                                  NaN
#
#                                                 March  April  \
# 0                                                 NaN    NaN
# 1                                                 NaN    NaN
# 2                                                 NaN    NaN
# 3                                                 NaN    NaN
# 4                                                 NaN    NaN
# 5                                                 NaN    NaN
# 6                                                 NaN    NaN
# 7                                                 NaN    NaN
# 8                                                 NaN    NaN
# 9                                                 NaN    NaN
# 10                                                NaN    NaN
# 11                                                NaN    NaN
# 12                                                NaN    NaN
# 13  "Ethnic hatred has been unleashed in Myanmar s...    NaN
#
#                                                   May  June  \
# 0                                                 NaN   NaN
# 1                                                 NaN   NaN
# 2                                                 NaN   NaN
# 3                                                 NaN   NaN
# 4                                                 NaN   NaN
# 5                                                 NaN   NaN
# 6                                                 NaN   NaN
# 7                                                 NaN   NaN
# 8                                                 NaN   NaN
# 9                                                 NaN   NaN
# 10  "While Mr. Kara-Murza survived, few others in ...   NaN
# 11                                                NaN   NaN
# 12                                                NaN   NaN
# 13                                                NaN   NaN
#
#                                                  July  August  \
# 0                                                 NaN     NaN
# 1                                                 NaN     NaN
# 2                                                 NaN     NaN
# 3                                                 NaN     NaN
# 4   " ... American Special Operations forces bombe...     NaN
# 5                                                 NaN     NaN
# 6                                                 NaN     NaN
# 7                                                 NaN     NaN
# 8                                                 NaN     NaN
# 9   The data also shows a sharp increase in the nu...     NaN
# 10                                                NaN     NaN
# 11                                                NaN     NaN
# 12                                                NaN     NaN
# 13                                                NaN     NaN
#
#                                             September  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   On Sept. 2, Buddhist villagers and Myanmar tro...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
#
#                                             October  \
# 0   Hamas’ lethal attack in southern Israel (2023)
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
# 10                                              NaN
# 11                                              NaN
# 12                                              NaN
# 13                                              NaN
#
#                                              November  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   "... After observing a man dragging an “unknow...
# 4                                                 NaN
# 5   "With at least tens of thousands of detainees ...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
#
#                                              December  Unnamed: 15  \
# 0                                                 NaN          NaN
# 1                                                 NaN          NaN
# 2                                                 NaN          NaN
# 3                                                 NaN          NaN
# 4                                                 NaN          NaN
# 5                                                 NaN          NaN
# 6                                                 NaN          NaN
# 7                                                 NaN          NaN
# 8                                                 NaN          NaN
# 9                                                 NaN          NaN
# 10                                                NaN          NaN
# 11                                                NaN          NaN
# 12  As the Ebola epidemic intensifies across parts...          NaN
# 13                                                NaN          NaN
#
#         Event Time                                Related Major Event
# 0          October    Hamas’ lethal attack in southern Israel (2023)
# 1         February                Russia’s invasion of Ukraine (2022)
# 2             2014  " … a hidden Pentagon archive of the American ...
# 3         November  "... After observing a man dragging an “unknow...
# 4             July  " ... American Special Operations forces bombe...
# 5      End of 2017  "With at least tens of thousands of detainees ...
# 6             2016  "In 2006, Russian President Vladimir V. Putin ...
# 7             2015  "The war in Yemen began in March 2015 after Ho...
# 8        September  On Sept. 2, Buddhist villagers and Myanmar tro...
# 9             July  "The data also shows a sharp increase in the n...
# 10             May  "While Mr. Kara-Murza survived, few others in ...
# 11            2013  "Parveena’s story — she was one of six policew...
# 12  December, 2013  "As the Ebola epidemic intensifies across part...
# 13           March  "Ethnic hatred has been unleashed in Myanmar s...

# %% [markdown]
# # Word Cloud:

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import numpy as np
from PIL import Image

# Read the Excel file
df = pd.read_excel('news_org_counts.xlsx')

# Print the data for verification
print(df.head())

# Create a dictionary for word frequencies
word_freq = dict(zip(df['News Organization'], df['count']))

# Define a custom colormap - blue to red gradient
colors = ['#1E88E5', '#5E35B1', '#D81B60', '#E53935']
custom_cmap = LinearSegmentedColormap.from_list('custom_colormap', colors)

# Set up the wordcloud
wc = WordCloud(
    width=1200, 
    height=800,
    background_color='white',
    colormap=custom_cmap,
    prefer_horizontal=0.9,  # Allow some vertical text to improve layout
    max_words=30,  # We have 27 organizations, make sure all fit
    relative_scaling=0.5,  # Lower value gives less extreme size differences
    min_font_size=8,  # Smaller minimum font size
    max_font_size=100,
    random_state=42,  # For reproducibility
    collocations=False  # Prevent merging of phrases
)

# Print the total number of organizations to ensure all are included
print(f"Total organizations to include: {len(word_freq)}")

# Generate the wordcloud from frequencies
wordcloud = wc.generate_from_frequencies(word_freq)

# Verify how many words were included
print(f"Words included in wordcloud: {len(wordcloud.words_)}")

# Plot the wordcloud
plt.figure(figsize=(10, 8), dpi=300)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.tight_layout(pad=0)

# Save as SVG
plt.savefig('news_organization_wordcloud.svg', format='svg', bbox_inches='tight')
print("Word cloud saved as 'news_organization_wordcloud.svg'")

# Also save as PNG for easy viewing
plt.savefig('news_organization_wordcloud.png', format='png', bbox_inches='tight')
print("Word cloud also saved as 'news_organization_wordcloud.png'")

# Show the word cloud (comment out if running on a server without display)
plt.show()
# Out:
#          News Organization  count
# 0       The New York Times     30
# 1      The Washington Post      9
# 2  The Wall Street Journal      5
# 3     The Associated Press      6
# 4                  Newsday      4
# Total organizations to include: 27
# Words included in wordcloud: 27
# Word cloud saved as 'news_organization_wordcloud.svg'
# Word cloud also saved as 'news_organization_wordcloud.png'

# %%
#!/usr/bin/env python

import os
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# 假设你已经将数据存储在一个字典中
news_org_counts = {
    "The New York Times": 30,
    "The Washington Post": 9,
    "The Wall Street Journal": 5,
    "The Associated Press": 6,
    "Newsday": 4,
    "The Christian Science Monitor": 3,
    "Reuters": 3,
    "Los Angeles Times": 3,
    "The Baltimore Sun": 2,
    "Chicago Tribune": 2,
    "The Village Voice": 1,
    "Unknown": 1,
    "The Milwaukee Journal": 1,
    "Scripps-Howard Newspapers": 1,
    "International News Service": 1,
    "United Press": 1,
    "New York Daily News": 1,
    "New York Herald Tribune Syndicate": 1,
    "The Miami News": 1,
    "Philadelphia Bulletin": 1,
    "Dispatch News Service": 1,
    "The Philadelphia Inquirer": 1,
    "Louisville Courtier-Journal": 1,
    "BuzzFeed News": 1,
    "San Jose Mercury News": 1,
    "The Dallas Morning News": 1,
    "The Miami Herald": 1,
}

# 生成词云
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(news_org_counts)

# 显示词云
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

file_path = '/Users/yushuowang/Desktop/1Columbia/Data Journalism/Data Studio/Data-driven Pitches/Pulizer Prize New/news_org_counts.xlsx' 
df = pd.read_excel(file_path)

# Change the dataframe to a dictionary for the word cloud to work
# 假设 Excel 文件中第一列是媒体名称，第二列是出现次数
news_org_counts = dict(zip(df.iloc[:, 0], df.iloc[:, 1])) # Column 1: df.iloc[:, 0]

# Generate Word Cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(news_org_counts)

# Show Word Cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# importing libraries

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image
from wordcloud import WordCloud, ImageColorGenerator

# %%
# word cloud will be made with the shape of this image

background_image = np.array(Image.open('/Users/yushuowang/Desktop/1Columbia/Data Journalism/Data Studio/Data-driven Pitches/Pulizer Prize New/Pulitzer_Prizes_Medal.png'))
plt.imshow(background_image)

# %%
# Creating word_cloud with text as argument in .generate() method
word_cloud2 = WordCloud(background_color = 'white',mask = background_image, 
               width = 2048, height = 1080).generate_from_frequencies(news_org_counts)

# font color matching the masked image
img_colors = ImageColorGenerator(background_image)
word_cloud2.recolor(color_func = img_colors)

#saving the image
word_cloud2.to_file('disney.svg')
